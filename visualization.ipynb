# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
DATASET_PATH = '../Dataset/FINAL_DATA_SET/'
DATASET_NAME = 'DATA_SET_11_7.csv'

# %%
df = pd.read_csv(DATASET_PATH+DATASET_NAME)
df.head(10)
# Out:
#    restaurant_id adress_x        a_name  user_id  rate                 time  \
# 0           2058      مزة    ملك الغربي    88758   NaN  2020-04-17 10:15:21
# 1           2058      مزة    ملك الغربي    88758   NaN  2020-04-17 10:15:21
# 2           2060  الشعلان  باغيت: شعلان    88758  10.0  2020-03-21 19:50:25
# 3           2060  الشعلان  باغيت: شعلان    88758  10.0  2020-03-21 19:50:25
# 4           2060  الشعلان  باغيت: شعلان    88758  10.0  2020-03-21 19:50:25
# 5           2060  الشعلان  باغيت: شعلان    88758  10.0  2020-03-21 19:50:25
# 6           2075      مزة         وينجو    88758  10.0  2020-05-05 15:08:33
# 7           2075      مزة         وينجو    88758   NaN  2020-05-02 18:08:30
# 8           2075      مزة         وينجو    88758  10.0  2020-05-05 15:08:33
# 9           2075      مزة         وينجو    88758  10.0  2020-05-05 15:08:33
#
#    total_x  paid     id_y  dish_id  ...        C8        C9       C10  \
# ...

# %%
sns.countplot(df['cluster_y'])

# %%
sns.countplot(df['cluster_x'])

# %%
plt.rcdefaults()
sns.set(font_scale = 1)
plt.pie(df['cluster_x'].value_counts(),autopct='%.2f',radius=1.8,explode=[0,0,0,0,0,0,0,0.5,0.5,0.0,0.0,1.0],
        shadow=False,labels=df['cluster_x'].unique().tolist())
# Out:
# ([<matplotlib.patches.Wedge at 0x17e5f5bae48>,
# ...
#  [Text(0.8277818819775307, 1.7986598221647523, '8'),
#   Text(-1.9750659366261727, 0.13969447368804583, '0'),
#   Text(-0.6945301308289356, -1.8541919796425457, '10'),
#   Text(0.584249512964746, -1.891838393362514, '5'),
#   Text(1.1303722122665254, -1.6256256216409983, '3'),
#   Text(1.5159591353919724, -1.2736828097378186, '9'),
#   Text(1.775737851123905, -0.8758738973652871, '1'),
#   Text(2.3945625765845864, -0.6453449208141234, '7'),
#   Text(2.4528810445621776, -0.3657520761766938, '6'),
#   Text(1.9733109688831914, -0.16261555917341108, '2'),
#   Text(1.9790788511811812, -0.060389575320388876, '4'),
#   Text(2.979981105849631, -0.010611728380084201, '11')],
#  [Text(0.45151739016956216, 0.9810871757262285, '36.27'),
#   Text(-1.0773086927051851, 0.07619698564802499, '25.21'),
#   Text(-0.378834616815783, -1.0113774434413885, '15.63'),
#   Text(0.3186815525262251, -1.0319118509250076, '5.31'),
# ...
